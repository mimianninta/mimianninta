# %%
pwd
# Out:
# '/home/rajashree/PyTorch-YOLOv3'

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/07/08/a549ba8b061005bb629b76adc000f3caaaf881028b963c2e18f811c6edc1/numpy-1.18.2-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#     100% |████████████████████████████████| 12.4MB 15kB/s ta 0:00:017
# ...
#   Using cached https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl
# ...

# %%
# !python3 detect.py --dataset fish --image_folder data/samplefishes/
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.8, dataset='fish', image_folder='data/samplefishes/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='weights/yolov3_fish.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:01.110904
# 	+ Batch 1, Inference Time: 0:00:00.487511
# 	+ Batch 2, Inference Time: 0:00:00.532618
# 	+ Batch 3, Inference Time: 0:00:00.527990
# 	+ Batch 4, Inference Time: 0:00:00.441594
# 	+ Batch 5, Inference Time: 0:00:00.474267
# 	+ Batch 6, Inference Time: 0:00:00.475371
# 	+ Batch 7, Inference Time: 0:00:00.454131
# 	+ Batch 8, Inference Time: 0:00:00.427675
#
# Saving images:
# (0) Image: 'data/samplefishes/DSCN4065_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (1) Image: 'data/samplefishes/DSCN4125_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (2) Image: 'data/samplefishes/DSCN4142_1.jpg'
# 	+ Label: fish, Conf: 1.00000
# ...

# %%
# !python3 detect.py --dataset fish --image_folder data/samplefishes/
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.8, dataset='fish', image_folder='data/samplefishes/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='weights/yolov3_fish.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.532158
# 	+ Batch 1, Inference Time: 0:00:00.421240
# 	+ Batch 2, Inference Time: 0:00:00.483362
# 	+ Batch 3, Inference Time: 0:00:00.484318
# 	+ Batch 4, Inference Time: 0:00:00.490213
# 	+ Batch 5, Inference Time: 0:00:00.447174
# 	+ Batch 6, Inference Time: 0:00:00.500934
# 	+ Batch 7, Inference Time: 0:00:00.470230
# 	+ Batch 8, Inference Time: 0:00:00.469455
#
# Saving images:
# (0) Image: 'data/samplefishes/DSCN4065_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (1) Image: 'data/samplefishes/DSCN4125_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (2) Image: 'data/samplefishes/DSCN4142_1.jpg'
# 	+ Label: fish, Conf: 1.00000
# ...

# %%
# !python3 detect.py --dataset fish --image_folder data/samplefishes/
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.8, dataset='fish', image_folder='data/samplefishes/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='weights/yolov3_fish.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.498866
# 	+ Batch 1, Inference Time: 0:00:00.431202
# 	+ Batch 2, Inference Time: 0:00:00.450163
# 	+ Batch 3, Inference Time: 0:00:00.434938
# 	+ Batch 4, Inference Time: 0:00:00.441238
# 	+ Batch 5, Inference Time: 0:00:00.519732
# 	+ Batch 6, Inference Time: 0:00:00.517205
# 	+ Batch 7, Inference Time: 0:00:00.433226
# 	+ Batch 8, Inference Time: 0:00:00.470897
#
# Saving images:
# (0) Image: 'data/samplefishes/DSCN4065_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# 	+ Label: fish, Conf: 1.00000
# (1) Image: 'data/samplefishes/DSCN4125_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (2) Image: 'data/samplefishes/DSCN4142_1.jpg'
# ...

# %%
# !python3 detect.py --dataset fish --image_folder data/sample_open_images/
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.8, dataset='fish', image_folder='data/sample_open_images/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='weights/yolov3_fish.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.535286
# 	+ Batch 1, Inference Time: 0:00:00.432362
# 	+ Batch 2, Inference Time: 0:00:00.443284
# 	+ Batch 3, Inference Time: 0:00:00.490235
# 	+ Batch 4, Inference Time: 0:00:00.489997
# 	+ Batch 5, Inference Time: 0:00:00.508018
# 	+ Batch 6, Inference Time: 0:00:00.481549
# 	+ Batch 7, Inference Time: 0:00:00.463303
# 	+ Batch 8, Inference Time: 0:00:00.457539
# 	+ Batch 9, Inference Time: 0:00:00.449162
# 	+ Batch 10, Inference Time: 0:00:00.435969
# 	+ Batch 11, Inference Time: 0:00:00.458888
# 	+ Batch 12, Inference Time: 0:00:00.498558
# 	+ Batch 13, Inference Time: 0:00:00.442076
# 	+ Batch 14, Inference Time: 0:00:00.426406
#
# ...

# %%
# !python3 detect.py --dataset fish --image_folder data/samplefishes/
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.8, dataset='fish', image_folder='data/samplefishes/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='weights/yolov3_fish.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.519658
# 	+ Batch 1, Inference Time: 0:00:00.418124
# 	+ Batch 2, Inference Time: 0:00:00.473292
# 	+ Batch 3, Inference Time: 0:00:00.468161
# 	+ Batch 4, Inference Time: 0:00:00.498767
# 	+ Batch 5, Inference Time: 0:00:00.505767
# 	+ Batch 6, Inference Time: 0:00:00.470403
# 	+ Batch 7, Inference Time: 0:00:00.476248
# 	+ Batch 8, Inference Time: 0:00:00.477345
#
# Saving images:
# (0) Image: 'data/samplefishes/DSCN4065_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (1) Image: 'data/samplefishes/DSCN4125_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (2) Image: 'data/samplefishes/DSCN4142_1.jpg'
# 	+ Label: fish, Conf: 1.00000
# ...

# %%
# !python3 detect.py --dataset fish --image_folder data/samplefishes/
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.8, dataset='fish', image_folder='data/samplefishes/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='weights/yolov3_fish.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.522712
# 	+ Batch 1, Inference Time: 0:00:00.440215
# 	+ Batch 2, Inference Time: 0:00:00.483862
# 	+ Batch 3, Inference Time: 0:00:00.477744
# 	+ Batch 4, Inference Time: 0:00:00.490900
# 	+ Batch 5, Inference Time: 0:00:00.470223
# 	+ Batch 6, Inference Time: 0:00:00.557041
# 	+ Batch 7, Inference Time: 0:00:00.531689
# 	+ Batch 8, Inference Time: 0:00:00.490974
#
# Saving images:
# (0) Image: 'data/samplefishes/DSCN4065_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (1) Image: 'data/samplefishes/DSCN4125_C.jpg'
# 	+ Label: fish, Conf: 1.00000
# (2) Image: 'data/samplefishes/DSCN4142_1.jpg'
# 	+ Label: fish, Conf: 1.00000
# ...

# %%
pwd
# Out:
# '/home/rajashree/PyTorch-YOLOv3'
